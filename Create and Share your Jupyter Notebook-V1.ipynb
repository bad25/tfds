# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkST0151ENSkillsNetwork20531532-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# #### Import the required libraries we need for the lab.

# %%
import piplite
await piplite.install(['numpy'],['pandas'])
await piplite.install(['seaborn'])

# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
import numpy as np
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Read the dataset in the csv file from the URL

# %%
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

# %%
boston_df=pd.read_csv(boston_url)

# %% [markdown]
# #### Add your code below following the instructions given in the course to complete the peer graded assignment

# %%
boston_df.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO  LSTAT  MEDV
# 0  296.0     15.3   4.98  24.0
# 1  242.0     17.8   9.14  21.6
# 2  242.0     17.8   4.03  34.7
# 3  222.0     18.7   2.94  33.4
# 4  222.0     18.7   5.33  36.2

# %%
# Create a boxplot for the median value of owner-occupied homes (MEDV)
pyplot.figure(figsize=(8, 6))
pyplot.boxplot(boston_df['MEDV'], vert=False)
pyplot.xlabel('Median Value of Owner-Occupied Homes (MEDV)')
pyplot.title('Boxplot of MEDV')
pyplot.show()

# %%
# Count the occurrences of each unique value in the 'CHAS' column
chas_counts = boston_df['CHAS'].value_counts()
# Create a bar plot for the 'CHAS' variable
pyplot.figure(figsize=(6, 4))
chas_counts.plot(kind='bar', color='skyblue')
pyplot.xlabel('Charles River (CHAS)')
pyplot.ylabel('Count')
pyplot.title('Bar Plot of CHAS')
pyplot.xticks(rotation=0, ticks=[0, 1], labels=['Not on Charles River', 'On Charles River'])
pyplot.show()

# %%
# Create a boxplot for the MEDV variable vs the AGE variable
pyplot.figure(figsize=(10, 6))
pyplot.boxplot([boston_df[boston_df['AGE'] < 50]['MEDV'], 
             boston_df[(boston_df['AGE'] >= 50) & (boston_df['AGE'] < 75)]['MEDV'],
             boston_df[boston_df['AGE'] >= 75]['MEDV']],
            labels=['AGE < 50', '50 <= AGE < 75', 'AGE >= 75'])
pyplot.xlabel('Age Categories')
pyplot.ylabel('Median Value of Owner-Occupied Homes (MEDV)')
pyplot.title('Boxplot of MEDV vs AGE')
pyplot.show()

# %%
# Create a scatter plot for NOX vs INDUS
pyplot.figure(figsize=(10, 6))
pyplot.scatter(boston_df['INDUS'], boston_df['NOX'], color='skyblue')
pyplot.xlabel('Proportion of Non-Retail Business Acres per Town (INDUS)')
pyplot.ylabel('Nitric Oxide Concentrations (NOX)')
pyplot.title('Scatter Plot: NOX vs INDUS')
pyplot.grid(True)
pyplot.show()

# %%
# Create a histogram for the PTRATIO variable
pyplot.figure(figsize=(8, 6))
pyplot.hist(boston_df['PTRATIO'], bins=15, color='skyblue')
pyplot.xlabel('Pupil-Teacher Ratio (PTRATIO)')
pyplot.ylabel('Frequency')
pyplot.title('Histogram of PTRATIO')
pyplot.grid(True)
pyplot.show()

# %%
# Extract the features (DIS) and target (MEDV)
X = boston_df[['DIS']]
y = boston_df['MEDV']

# Fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Coefficient for DIS
coefficient = model.coef_[0]
print('Coefficient for DIS:', coefficient)
# Out:
# Coefficient for DIS: 1.0916130158411097

# %%
# Create a histogram for the PTRATIO variable
pyplot.figure(figsize=(8, 6))
pyplot.hist(boston_df['PTRATIO'], bins=15, color='skyblue')
pyplot.xlabel('Pupil-Teacher Ratio (PTRATIO)')
pyplot.ylabel('Frequency')
pyplot.title('Histogram of Pupil-Teacher Ratio (PTRATIO)')
pyplot.grid(True)
pyplot.show()

# %%
# Create a scatter plot for NOX vs INDUS
pyplot.figure(figsize=(10, 6))
pyplot.scatter(boston_df['INDUS'], boston_df['NOX'], color='skyblue')
pyplot.xlabel('Proportion of Non-Retail Business Acres per Town (INDUS)')
pyplot.ylabel('Nitric Oxide Concentrations (NOX)')
pyplot.title('Scatter Plot: Nitric Oxide Concentrations vs. INDUS')
pyplot.grid(True)
pyplot.show()

# %%
import matplotlib.pyplot as plt

# Create a histogram for the PTRATIO variable
plt.figure(figsize=(8, 6))
plt.hist(boston_df['PTRATIO'], bins=15, color='skyblue')
plt.xlabel('Pupil-Teacher Ratio (PTRATIO)')
plt.ylabel('Frequency')
plt.title('Histogram of Pupil-Teacher Ratio (PTRATIO)')
plt.grid(True)
plt.show()

# Print interpretations
print("Interpretations:")
print("1. The distribution shape indicates the frequency of different PTRATIO values.")
print("2. The histogram helps visualize the frequency distribution within certain PTRATIO ranges.")
print("3. The presence of multiple peaks suggests potential subgroupings or patterns.")
# Out:
# Interpretations:
# 1. The distribution shape indicates the frequency of different PTRATIO values.
# 2. The histogram helps visualize the frequency distribution within certain PTRATIO ranges.
# 3. The presence of multiple peaks suggests potential subgroupings or patterns.

# %%
import matplotlib.pyplot as plt
# For the "Median value of owner-occupied homes" provide a boxplot
sns.boxplot(x = "MEDV", data = boston_df)
plt.title("Median value of owner-occupied homes")
plt.show()

# %%
# Provide a  bar plot for the Charles river variable
sns.catplot(x='CHAS', kind='count', data= boston_df)
plt.title("Charles River variable")
plt.show()

# %%
# Provide a boxplot for the MEDV variable vs the AGE variable. (Discretize the age variable into three groups of 35 years and younger, between 35 and 70 years and 70 years and older)
boston_df.loc[(boston_df["AGE"] <= 35), "AGE_GROUP"] = "35 years and younger"
boston_df.loc[(boston_df["AGE"] > 35) & (boston_df["AGE"] < 70), "AGE_GROUP"] = "between 35 and 70 years"
boston_df.loc[(boston_df["AGE"] >= 70), "AGE_GROUP"] = "70 years and older"

ax = sns.boxplot(x = "AGE_GROUP", y = "MEDV", data = boston_df)
plt.title("The MEDV variable vs Groups AGE variable")
plt.show()

# %%
#Provide a scatter plot to show the relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town. 
scatter = sns.scatterplot(x='NOX', y='INDUS', data= boston_df)
plt.show()
# What can you say about the relationship? 
# There is a linear relationship

# %%
#Create a histogram for the pupil to teacher ratio variable
plt.figure(figsize=(8, 6))
sns.histplot(boston_df['PTRATIO'], kde=False, color='skyblue')
plt.xlabel('Pupil-Teacher Ratio (PTRATIO)')
plt.ylabel('Frequency')
plt.title('Histogram of Pupil-Teacher Ratio (PTRATIO)')
plt.grid(True)
plt.show()

# %%
# Is there a significant difference in median value of houses bounded by the Charles river or not? (T-test for independent samples)

ax = sns.histplot(boston_df['MEDV'], kde=False, color='skyblue')
ax.set(xlabel='Normal Distribution', ylabel='Frequency')
plt.show()
## we can assume it is normal

#We can use the Levene's Test in Python to check test significance
scipy.stats.levene(boston_df[boston_df['CHAS'] == 1]['MEDV'],
                   boston_df[boston_df['CHAS'] == 0]['MEDV'], center='mean')

# since the p-value is greater than 0.05 we can assume equality of variance, but, in this case is 0.0032 less than 0.05, 
# the variance are not equal, for the purposes of this exercise, we will move along

scipy.stats.ttest_ind(boston_df[boston_df['CHAS'] == 1]['MEDV'],
                   boston_df[boston_df['CHAS'] == 0]['MEDV'], equal_var = True)
# Out:
# Ttest_indResult(statistic=3.996437466090509, pvalue=7.390623170519905e-05)

# %%
# Is there a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)? (ANOVA)
# State the hypothesis
# H_0: µ_1 = µ_2 = µ_3 (the three population means are equal)
# H_1: At least one of the means different

scipy.stats.levene(boston_df[boston_df['AGE_GROUP'] == '35 years and younger']['MEDV'],
                   boston_df[boston_df['AGE_GROUP'] == 'between 35 and 70 years']['MEDV'], 
                   boston_df[boston_df['AGE_GROUP'] == '70 years and older']['MEDV'], 
                   center='mean')
# since the p-value is greater than 0.05, pvalue = 0.06, the variance are equal

# First, separate the three samples (one for each job category) into a variable each.
thirtyfive_lower = boston_df[boston_df['AGE_GROUP'] == '35 years and younger']['MEDV']
thirtyfive_seventy = boston_df[boston_df['AGE_GROUP'] == 'between 35 and 70 years']['MEDV']
seventy_older = boston_df[boston_df['AGE_GROUP'] == '70 years and older']['MEDV']

# Now, run a one-way ANOVA
f_statistic, p_value = scipy.stats.f_oneway(thirtyfive_lower, thirtyfive_seventy, seventy_older)
print("F_Statistic: {0}, P-Value: {1}".format(f_statistic,p_value))
# Out:
# F_Statistic: 36.40764999196599, P-Value: 1.7105011022702984e-15

# %%
# Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)
scipy.stats.pearsonr(boston_df['NOX'], boston_df['INDUS'])
# Out:
# PearsonRResult(statistic=0.7636514469209189, pvalue=7.913361061211254e-98)

# %%
# What is the impact of an additional weighted distance to the five Boston employment centres on the median value of owner occupied homes? (Regression analysis)
## X is the input variables (or independent variables)
X = boston_df['DIS']
## y is the target/dependent variable
y = boston_df['MEDV']
## add an intercept (beta_0) to our model
X = sm.add_constant(X) 

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Print out the statistics
model.summary()

# Conclusion: Like the t-test, the p-value is less than the alpha (α) level = 0.05, the impact of "DIS" is 1.0916 on "MEDV".
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Wed, 11 Oct 2023   Prob (F-statistic):           1.21e-08
# Time:                        10:10:38   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.3901      0.817     22.499      0.000      16.784      19.996
# ...
